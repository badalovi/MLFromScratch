# %% [markdown]
# ##### This notebook is prepared to give a brief example on how to apply LinRegClass in practice for better understanding.

# %%
import pandas as pd
import numpy as np
from main import LinRegGradient

# %%
X = np.array([[20, 24, 26, 30, 35], [0.5, 0.8, 1.0, 1.5, 1.7], [2.5, 3.0, 3.7, 4.0, 4.8]])
X = X.transpose()

y = np.array([80,120,140,150,170])

# %%
glr = LinRegGradient()
glr.fit(X, y, np.zeros(3), 0, 0.000075, 100)
glr.plot_cost()
glr.coef_
# Out:
# Iteration    0: Cost  8154.18
# Iteration   10: Cost  2510.58
# Iteration   20: Cost   796.66
# Iteration   30: Cost   276.15
# Iteration   40: Cost   118.07
# Iteration   50: Cost    70.07
# Iteration   60: Cost    55.49
# Iteration   70: Cost    51.06
# Iteration   80: Cost    49.71
# Iteration   90: Cost    49.30
# [0.1661161921531939, array([4.8019864 , 0.21015296, 0.65127612])]
